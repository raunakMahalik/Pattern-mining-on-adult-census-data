# %%
import pandas as pd
import time
import numpy as np
from itertools import combinations
import random

# %%
df = pd.read_excel('adult_census.xlsx')
'''It appears that 'fnlwgt' column is something similar to an ID, hence we can drop it.
   Moreover, I feel that the 'education-num' column too can be discarded.
'''
df.drop(['fnlwgt', 'education-num'], axis=1, inplace=True)
df.head()
# Out:
#    age          workclass   education       marital-status  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
# 3   53            Private        11th   Married-civ-spouse
# 4   28            Private   Bachelors   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country  income
# 0             0              40   United-States   <=50K
# 1             0              13   United-States   <=50K
# 2             0              40   United-States   <=50K
# 3             0              40   United-States   <=50K
# 4             0              40            Cuba   <=50K

# %%
''' The data set has many missing values represented by '?' this might
    create erroneous patterns when we find association rules. Hence, let
    us drop all the rows containing ' ?'
'''
df = df.replace(' ?', np.NaN)
df.dropna(axis = 0, inplace = True)
df.reset_index(drop= True, inplace= True)
df.head(50)
# Out:
#     age          workclass      education          marital-status  \
# 0    39          State-gov      Bachelors           Never-married
# 1    50   Self-emp-not-inc      Bachelors      Married-civ-spouse
# 2    38            Private        HS-grad                Divorced
# 3    53            Private           11th      Married-civ-spouse
# 4    28            Private      Bachelors      Married-civ-spouse
# 5    37            Private        Masters      Married-civ-spouse
# 6    49            Private            9th   Married-spouse-absent
# 7    52   Self-emp-not-inc        HS-grad      Married-civ-spouse
# 8    31            Private        Masters           Never-married
# 9    42            Private      Bachelors      Married-civ-spouse
# 10   37            Private   Some-college      Married-civ-spouse
# 11   30          State-gov      Bachelors      Married-civ-spouse
# 12   23            Private      Bachelors           Never-married
# 13   32            Private     Assoc-acdm           Never-married
# 14   34            Private        7th-8th      Married-civ-spouse
# 15   25   Self-emp-not-inc        HS-grad           Never-married
# 16   32            Private        HS-grad           Never-married
# 17   38            Private           11th      Married-civ-spouse
# 18   43   Self-emp-not-inc        Masters                Divorced
# 19   40            Private      Doctorate      Married-civ-spouse
# 20   54            Private        HS-grad               Separated
# 21   35        Federal-gov            9th      Married-civ-spouse
# 22   43            Private           11th      Married-civ-spouse
# 23   59            Private        HS-grad                Divorced
# 24   56          Local-gov      Bachelors      Married-civ-spouse
# 25   19            Private        HS-grad           Never-married
# 26   39            Private        HS-grad                Divorced
# 27   49            Private        HS-grad      Married-civ-spouse
# 28   23          Local-gov     Assoc-acdm           Never-married
# 29   20            Private   Some-college           Never-married
# 30   45            Private      Bachelors                Divorced
# 31   30        Federal-gov   Some-college      Married-civ-spouse
# 32   22          State-gov   Some-college      Married-civ-spouse
# 33   48            Private           11th           Never-married
# 34   21            Private   Some-college           Never-married
# 35   19            Private        HS-grad       Married-AF-spouse
# 36   48   Self-emp-not-inc     Assoc-acdm      Married-civ-spouse
# 37   31            Private            9th      Married-civ-spouse
# 38   53   Self-emp-not-inc      Bachelors      Married-civ-spouse
# 39   24            Private      Bachelors      Married-civ-spouse
# 40   49            Private        HS-grad               Separated
# 41   25            Private        HS-grad           Never-married
# 42   57        Federal-gov      Bachelors      Married-civ-spouse
# 43   53            Private        HS-grad      Married-civ-spouse
# 44   44            Private        Masters                Divorced
# 45   41          State-gov      Assoc-voc      Married-civ-spouse
# 46   29            Private      Assoc-voc           Never-married
# 47   25            Private   Some-college      Married-civ-spouse
# 48   47            Private    Prof-school      Married-civ-spouse
# 49   50        Federal-gov      Bachelors                Divorced
#
#             occupation    relationship                 race      sex  \
# 0         Adm-clerical   Not-in-family                White     Male
# 1      Exec-managerial         Husband                White     Male
# 2    Handlers-cleaners   Not-in-family                White     Male
# 3    Handlers-cleaners         Husband                Black     Male
# 4       Prof-specialty            Wife                Black   Female
# 5      Exec-managerial            Wife                White   Female
# 6        Other-service   Not-in-family                Black   Female
# 7      Exec-managerial         Husband                White     Male
# 8       Prof-specialty   Not-in-family                White   Female
# 9      Exec-managerial         Husband                White     Male
# 10     Exec-managerial         Husband                Black     Male
# 11      Prof-specialty         Husband   Asian-Pac-Islander     Male
# 12        Adm-clerical       Own-child                White   Female
# 13               Sales   Not-in-family                Black     Male
# 14    Transport-moving         Husband   Amer-Indian-Eskimo     Male
# 15     Farming-fishing       Own-child                White     Male
# 16   Machine-op-inspct       Unmarried                White     Male
# 17               Sales         Husband                White     Male
# 18     Exec-managerial       Unmarried                White   Female
# 19      Prof-specialty         Husband                White     Male
# 20       Other-service       Unmarried                Black   Female
# 21     Farming-fishing         Husband                Black     Male
# 22    Transport-moving         Husband                White     Male
# 23        Tech-support       Unmarried                White   Female
# 24        Tech-support         Husband                White     Male
# 25        Craft-repair       Own-child                White     Male
# 26     Exec-managerial   Not-in-family                White     Male
# 27        Craft-repair         Husband                White     Male
# 28     Protective-serv   Not-in-family                White     Male
# 29               Sales       Own-child                Black     Male
# 30     Exec-managerial       Own-child                White     Male
# 31        Adm-clerical       Own-child                White     Male
# 32       Other-service         Husband                Black     Male
# 33   Machine-op-inspct       Unmarried                White     Male
# 34   Machine-op-inspct       Own-child                White     Male
# 35        Adm-clerical            Wife                White   Female
# 36      Prof-specialty         Husband                White     Male
# 37   Machine-op-inspct         Husband                White     Male
# 38      Prof-specialty         Husband                White     Male
# 39        Tech-support         Husband                White     Male
# 40        Adm-clerical       Unmarried                White   Female
# 41   Handlers-cleaners   Not-in-family                White     Male
# 42      Prof-specialty         Husband                Black     Male
# 43   Machine-op-inspct         Husband                White     Male
# 44     Exec-managerial       Unmarried                White   Female
# 45        Craft-repair         Husband                White     Male
# 46      Prof-specialty   Not-in-family                White     Male
# 47     Exec-managerial            Wife                Other   Female
# 48      Prof-specialty            Wife                White   Female
# 49     Exec-managerial   Not-in-family                White     Male
#
#     capital-gain  capital-loss  hours-per-week  native-country  income
# 0           2174             0              40   United-States   <=50K
# 1              0             0              13   United-States   <=50K
# 2              0             0              40   United-States   <=50K
# 3              0             0              40   United-States   <=50K
# 4              0             0              40            Cuba   <=50K
# 5              0             0              40   United-States   <=50K
# 6              0             0              16         Jamaica   <=50K
# 7              0             0              45   United-States    >50K
# 8          14084             0              50   United-States    >50K
# 9           5178             0              40   United-States    >50K
# 10             0             0              80   United-States    >50K
# 11             0             0              40           India    >50K
# 12             0             0              30   United-States   <=50K
# 13             0             0              50   United-States   <=50K
# 14             0             0              45          Mexico   <=50K
# 15             0             0              35   United-States   <=50K
# 16             0             0              40   United-States   <=50K
# 17             0             0              50   United-States   <=50K
# 18             0             0              45   United-States    >50K
# 19             0             0              60   United-States    >50K
# 20             0             0              20   United-States   <=50K
# 21             0             0              40   United-States   <=50K
# 22             0          2042              40   United-States   <=50K
# 23             0             0              40   United-States   <=50K
# 24             0             0              40   United-States    >50K
# 25             0             0              40   United-States   <=50K
# 26             0             0              80   United-States   <=50K
# 27             0             0              40   United-States   <=50K
# 28             0             0              52   United-States   <=50K
# 29             0             0              44   United-States   <=50K
# 30             0          1408              40   United-States   <=50K
# 31             0             0              40   United-States   <=50K
# 32             0             0              15   United-States   <=50K
# 33             0             0              40     Puerto-Rico   <=50K
# 34             0             0              40   United-States   <=50K
# 35             0             0              25   United-States   <=50K
# 36             0             0              40   United-States   <=50K
# 37             0             0              43   United-States   <=50K
# 38             0             0              40   United-States   <=50K
# 39             0             0              50   United-States   <=50K
# 40             0             0              40   United-States   <=50K
# 41             0             0              35   United-States   <=50K
# 42             0             0              40   United-States    >50K
# 43             0             0              38   United-States   <=50K
# 44             0             0              40   United-States   <=50K
# 45             0             0              40   United-States   <=50K
# 46             0             0              43   United-States   <=50K
# 47             0             0              40   United-States   <=50K
# 48             0          1902              60        Honduras    >50K
# 49             0             0              55   United-States    >50K

# %%
'''To apply Apriori algorithm we have to transform our cross-sectional data into a transactional one.
   In order to achieve this we can treat each tuple or row as a transaction but this mandates that all
   the columns must have cateogorical data for we are interested in generating association rules from a
   limited pool of items appearing in the transaction. To achieve this I have grouped continuous data into
   discrete bins.
'''

df['age'] = pd.cut(df['age'], bins = [0, 25, 50, 100],
                   labels = ['Young', 'Middle_age', 'Old'],
                   right = True, include_lowest = True)

df['hours-per-week'] = pd.cut(df['hours-per-week'], [0, 30, 50, 100],
                              labels = ['Part_time', 'Full_time', 'Extra_time'],
                              right = True, include_lowest = True)

df['capital-gain'] = pd.cut(df['capital-gain'], [0, 1, 50000, 100000],
                            labels = ['No_Gain', 'Medium_Gain', 'High_Gain'],
                            right = True, include_lowest = True)

df['capital-loss'] = pd.cut(df['capital-loss'], [0, 1, 50000, 100000],
                            labels = ['No_Loss', 'Medium_loss', 'High_Loss'],
                            right = True, include_lowest = True)
df.head()
# Out:
#           age          workclass   education       marital-status  \
# 0  Middle_age          State-gov   Bachelors        Never-married
# 1  Middle_age   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2  Middle_age            Private     HS-grad             Divorced
# 3         Old            Private        11th   Married-civ-spouse
# 4  Middle_age            Private   Bachelors   Married-civ-spouse
#
#            occupation    relationship    race      sex capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male  Medium_Gain
# 1     Exec-managerial         Husband   White     Male      No_Gain
# 2   Handlers-cleaners   Not-in-family   White     Male      No_Gain
# 3   Handlers-cleaners         Husband   Black     Male      No_Gain
# 4      Prof-specialty            Wife   Black   Female      No_Gain
#
#   capital-loss hours-per-week  native-country  income
# 0      No_Loss      Full_time   United-States   <=50K
# 1      No_Loss      Part_time   United-States   <=50K
# 2      No_Loss      Full_time   United-States   <=50K
# 3      No_Loss      Full_time   United-States   <=50K
# 4      No_Loss      Full_time            Cuba   <=50K

# %%
def get_candidates_1(datafrm):

    temp_candidates = {}

    for index, row in datafrm.iterrows():
        # Converting each row of adult census data into a transaction
        transaction = list(set(row))
        ''' Each element in a transaction is an item, the count of each item is maintained
            as key-value pair in a dictionary
        '''
        for item in transaction:
            if (item in temp_candidates.keys()):
                temp_candidates[item] += 1
            else:
                temp_candidates[item] = 1
    return temp_candidates

# %%
def generate_L1(d, c, minSupport):

    for key,value in c.items():
        if (value >= minSupport):
            d[key] = value
    return d

# %%
def join(frequentItemsets, k):
    cand_sets = []
    total_items = list(frequentItemsets.keys())
    singleUniqueElements = set()
    if (k>2):
        for item in set(total_items):
            singleUniqueElements = singleUniqueElements.union(item)
    else:
        singleUniqueElements = set(total_items)

    cand_sets = list(combinations(singleUniqueElements, k))

    return cand_sets

# %%
def has_infrequent_subset(item, prevFreqSet, k):
    
    candSubsets = set(combinations(item,(k-1)))
    
    if (not(candSubsets.issubset(prevFreqSet))):
        return True

    return False

def compute_support_count(candidateItemsets,dataFrm):
    
    candidateSets = {key:0 for key in candidateItemsets}
    
    for key,value in candidateSets.items():
        for index,row in dataFrm.iterrows():
            if(set(key).issubset(set(row))):
                candidateSets[key] += 1
                
    return candidateSets

def prune_itemsets(k, candidateItemsets, previousFrequentItemsets, minSupport, dataFrm):
    
    candidates ={}
    prevFreqSet = set(previousFrequentItemsets)

    for item in candidateItemsets:
        if(has_infrequent_subset(item, prevFreqSet, k)):
            candidateItemsets.remove(item)

    candidates = compute_support_count(candidateItemsets,dataFrm)
    print("Candidates after pruning:\n", candidates)
    
    return candidates

# %%
def generate_lk(candidateItemsets, minSupport):
    
    frequentItemsets = {}
    
    for item,count in candidateItemsets.items():
        if (count >= minSupport):
            frequentItemsets[item] = count

    return frequentItemsets

# %%
def perform_apriori(dataFrm, minSupportPercentage):

    minSupport = round((minSupportPercentage / 100.0) * len(dataFrm.index))
    print ('Minimum Support Count = ', minSupport)
    
    # Generating the 1st set of candidates C1
    candidateItemsets = get_candidates_1(dataFrm)
    
    # Generating 1st set of frequent itemsets L1
    frequentItemsets = {}
    frequentItemsets = generate_L1(frequentItemsets, candidateItemsets, minSupport)

    #totalFrequentItemsets = len(frequentItemsets)
    iteration = 1
    
    finalFrequentItemsets = {}
    finalFrequentItemsets.update(frequentItemsets)

    print('Set of frequent itemsets L1 : \n')
    for key,value in frequentItemsets.items():
        print(key, ' : ', value)
    
    while True:
        iteration += 1
        candidateItemsets = join(frequentItemsets, iteration)
        candidateItemsets = prune_itemsets(iteration, candidateItemsets,
                                          frequentItemsets, minSupport, dataFrm)
        frequentItemsets = generate_lk(candidateItemsets, minSupport)
        finalFrequentItemsets.update(frequentItemsets)
        
        if (bool(frequentItemsets)):
            print('Set of frequent itemsets L', iteration, ': \n')
            for key,value in frequentItemsets.items():
                print(key, ' : ', value, '\n')


        if len(frequentItemsets) == 0:
#             print('All frequent patterns: \n')
#             for key,value in finalFrequentItemsets.items():
#                 print(key, ' : ', value)
            break
    return

# %%
startTime = time.time()
perform_apriori(df 60)
totalRunTime = time.time() - startTime
print ('\n Total Execution Time: ', totalRunTime)
# Out:
# Minimum Support Count =  3
# Set of frequent itemsets L1 :
#
# E  :  4
# K  :  5
# Y  :  3
# M  :  3
# O  :  3
# Candidates after pruning:
#  {('E', 'Y'): 2, ('E', 'O'): 3, ('K', 'M'): 3, ('Y', 'M'): 2, ('M', 'O'): 1}
# Set of frequent itemsets L 2 :
#
# ('E', 'O')  :  3
#
# ('K', 'M')  :  3
#
# Candidates after pruning:
#  {('O', 'K', 'E'): 3, ('K', 'M', 'E'): 2}
# Set of frequent itemsets L 3 :
#
# ('O', 'K', 'E')  :  3
#
# Candidates after pruning:
#  {}
#
#  Total Execution Time:  0.003990650177001953

# %%
#Improved Apriori
def sampled_apriori(df, minSup, samplingFactor):
    
    #Perform a random sample of the dataframe
    df = df.sample(frac = samplingFactor).reset_index(drop = True)
    
    # We lower the minimum support in hope of capturing all global frequent patterns
    minSup = minSup*0.9
    
    startTime = time.time()
    perform_apriori(df, minSup)
    totalRunTime = time.time() - startTime
    print ('\n\n Total Execution Time: ', totalRunTime)

# %%
sampled_apriori(df,70,0.5)
# Out:
# Minimum Support Count =  9501
# Set of frequent itemsets L1 :
#
# No_Gain  :  13830
#  Private  :  11148
#  United-States  :  13749
#  <=50K  :  11320
#  Male  :  10127
# No_Loss  :  14351
# Full_time  :  11118
#  White  :  12983
# Candidates after pruning:
#  {('No_Gain', ' Private'): 10299, ('No_Gain', ' Male'): 9142, ('No_Gain', 'Full_time'): 10185, (' United-States', ' Private'): 10064, (' United-States', ' Male'): 9233, (' United-States', 'Full_time'): 10086, (' Private', ' <=50K'): 8671, (' Private', 'No_Loss'): 10647, (' Private', ' White'): 9610, (' <=50K', 'No_Loss'): 10957, (' <=50K', ' White'): 9587, (' Male', 'Full_time'): 7601, ('No_Loss', 'Full_time'): 10556, ('Full_time', ' White'): 9493}
# Set of frequent itemsets L 2 :
#
# ('No_Gain', ' Private')  :  10299
#
# ('No_Gain', 'Full_time')  :  10185
#
# (' United-States', ' Private')  :  10064
#
# (' United-States', 'Full_time')  :  10086
#
# (' Private', 'No_Loss')  :  10647
#
# (' Private', ' White')  :  9610
#
# (' <=50K', 'No_Loss')  :  10957
#
# (' <=50K', ' White')  :  9587
#
# ('No_Loss', 'Full_time')  :  10556
#
# Candidates after pruning:
#  {('No_Gain', ' <=50K', 'Full_time'): 7894, ('No_Gain', ' <=50K', ' Private'): 8326, ('No_Gain', 'No_Loss', 'Full_time'): 9623, ('No_Gain', 'No_Loss', ' Private'): 9798, ('No_Gain', 'Full_time', ' United-States'): 9214, ('No_Gain', 'Full_time', ' White'): 8670, ('No_Gain', ' United-States', ' White'): 11074, (' <=50K', 'No_Loss', 'Full_time'): 7958, (' <=50K', 'No_Loss', ' Private'): 8409, (' <=50K', 'Full_time', ' United-States'): 7416, (' <=50K', 'Full_time', ' White'): 6914, (' <=50K', ' United-States', ' White'): 8889, ('No_Loss', 'Full_time', ' United-States'): 9561, ('No_Loss', 'Full_time', ' White'): 8992, ('No_Loss', ' United-States', ' White'): 11494, ('Full_time', ' United-States', ' Private'): 7547, ('Full_time', ' Private', ' White'): 7216}
# Set of frequent itemsets L 3 :
#
# ('No_Gain', 'No_Loss', 'Full_time')  :  9623
#
# ('No_Gain', 'No_Loss', ' Private')  :  9798
#
# ('No_Gain', ' United-States', ' White')  :  11074
#
# ('No_Loss', 'Full_time', ' United-States')  :  9561
#
# ('No_Loss', ' United-States', ' White')  :  11494
#
# Candidates after pruning:
#  {('No_Gain', 'No_Loss', 'Full_time', ' Private'): 7348, ('No_Gain', 'No_Loss', ' United-States', ' Private'): 8816, ('No_Gain', 'No_Loss', ' Private', ' White'): 8402, ('No_Gain', 'Full_time', ' United-States', ' White'): 8044, ('No_Gain', ' United-States', ' Private', ' White'): 8183, ('No_Loss', 'Full_time', ' United-States', ' White'): 8347, ('No_Loss', ' United-States', ' Private', ' White'): 8473}
#
#
#  Total Execution Time:  39.690935373306274

# %%
'''
################TESTING BLOCK##############
'''
dic_2 = { 1: ['M', 'O', 'N', 'K', 'E', 'Y'],
        2: ['D', 'O', 'N', 'K', 'E', 'Y'],
        3: ['M', 'A', 'K', 'E', '#', '$'],
        4: ['M', 'U', 'C', 'K', 'Y', '%'],
        5: ['C', 'O', 'O', 'K', 'I', 'E']
}
data_test = pd.DataFrame(dic_2)
data_test= data_test.T
data_test.reset_index(drop = True)
'''
###########################################
'''
# Out:
# '\n###########################################\n'
